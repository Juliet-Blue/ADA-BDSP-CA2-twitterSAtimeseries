# %% [markdown]
# I'm cheating here and just side-stepping the big data database thing right now because I need to work on actually getting the sentiment analysis and time series working and this computer doesn't have mongdodb or spark installed. So I'm doing it in reverse, just to get things working.

# %%
import os
import glob
import json

# %%
#path = os.getcwd() + '/*.json'
path = '*.json'
files = glob.glob(path)
files
# Out:
# ['key_tweets_2021-11.json',
#  'key_tweets_2021-12.json',
#  'key_tweets_2022-01.json',
#  'key_tweets_2022-02.json',
#  'key_tweets_2022-03.json',
#  'key_tweets_2022-04.json',
#  'key_tweets_2022-05.json',
#  'key_tweets_2022-06.json',
#  'key_tweets_2022-07.json',
#  'key_tweets_2022-08.json',
#  'key_tweets_2022-09.json',
#  'key_tweets_2022-10.json',
#  'key_tweets_2022-11.json']

# %%
files[0]
# Out:
# 'key_tweets_2021-11.json'

# %%
import pandas as pd

# %%
pd.read_json(files[0], lines=True)
# Out:
#                                                      0
# 0    {'created_at': 'Mon Nov 01 02:02:27 +0000 2021...
# 1    {'created_at': 'Mon Nov 01 03:19:41 +0000 2021...
# 2    {'created_at': 'Mon Nov 01 03:19:49 +0000 2021...
# 3    {'created_at': 'Mon Nov 01 03:19:50 +0000 2021...
# 4    {'created_at': 'Mon Nov 01 03:20:34 +0000 2021...
# ..                                                 ...
# 521  {'created_at': 'Tue Nov 30 21:40:10 +0000 2021...
# 522  {'created_at': 'Tue Nov 30 23:18:44 +0000 2021...
# 523  {'created_at': 'Tue Nov 30 23:20:39 +0000 2021...
# 524  {'created_at': 'Tue Nov 30 23:27:09 +0000 2021...
# 525  {'created_at': 'Tue Nov 30 23:37:22 +0000 2021...
#
# [526 rows x 1 columns]

# %%
pd.json_normalize(files[0], max_level=1)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 pd.json_normalize(files[0], max_level=1)
#
# File D:\Juliet\Anaconda\lib\site-packages\pandas\io\json\_normalize.py:443, in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     441     data = list(data)
#     442 else:
# --> 443     raise NotImplementedError
#     445 # check to see if a simple recursive function is possible to
#     446 # improve performance (see #15621) but only for cases such
#     447 # as pd.Dataframe(data) or pd.Dataframe(data, sep)
#     448 if (
#     449     record_path is None
#     450     and meta is None
#    (...)
#     453     and max_level is None
#     454 ):
#
# NotImplementedError:

# %%
tweets = []
with open(files[0],'r', encoding="utf8") as f:
    for line in f:
        tweets.append(json.loads(line))

# %%
df = pd.json_normalize([json.loads(x) for x in open(files[0]).readlines()])

# %%
df
# Out:
#                                                      0
# 0    {'created_at': 'Mon Nov 01 02:02:27 +0000 2021...
# 1    {'created_at': 'Mon Nov 01 03:19:41 +0000 2021...
# 2    {'created_at': 'Mon Nov 01 03:19:49 +0000 2021...
# 3    {'created_at': 'Mon Nov 01 03:19:50 +0000 2021...
# 4    {'created_at': 'Mon Nov 01 03:20:34 +0000 2021...
# ..                                                 ...
# 521  {'created_at': 'Tue Nov 30 21:40:10 +0000 2021...
# 522  {'created_at': 'Tue Nov 30 23:18:44 +0000 2021...
# 523  {'created_at': 'Tue Nov 30 23:20:39 +0000 2021...
# 524  {'created_at': 'Tue Nov 30 23:27:09 +0000 2021...
# 525  {'created_at': 'Tue Nov 30 23:37:22 +0000 2021...
#
# [526 rows x 1 columns]

# %%
df[0].iloc[0]
# Out:
# {'created_at': 'Mon Nov 01 02:02:27 +0000 2021',
#  'text': '@mishacollins',
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'und',
#  'timestamp_ms': '1635732147661'}

# %%
json.dumps(df[0].iloc[0])
# Out:
# '{"created_at": "Mon Nov 01 02:02:27 +0000 2021", "text": "@mishacollins", "source": "<a href=\\"http://twitter.com/download/android\\" rel=\\"nofollow\\">Twitter for Android</a>", "\\n            \\"user\\": {\\n                \\"id\\": tweet_user_id,\\n                \\"name\\": tweet_user_name,\\n                \\"location\\": tweet_user_location,\\n                \\"url\\": tweet_user_url,\\n                \\"description\\": tweet_user_description,\\n                \\"verified\\": tweet_user_verified,\\n                \\"followers_count\\": tweet_user_follower_count,\\n                \\"friends_count\\": tweet_user_friends_count,\\n                \\"favourites_count\\": tweet_user_favourites_count,\\n                \\"statuses_count\\": tweet_user_statuses_count,\\n                \\"created_at\\": tweet_user_created_at,\\n                \\"utc_offset\\": tweet_user_utc_offset,\\n                \\"time_zone\\": tweet_user_timezone,\\n                \\"geo_enabled\\": tweet_user_geo_enabled,\\n                \\"lang\\": tweet_user_language,\\n                },\\n            lang": "und", "timestamp_ms": "1635732147661"}'

# %%
pd.DataFrame.from_dict(tweets)
# Out:
#                                                      0
# 0    {'created_at': 'Mon Nov 01 02:02:27 +0000 2021...
# 1    {'created_at': 'Mon Nov 01 03:19:41 +0000 2021...
# 2    {'created_at': 'Mon Nov 01 03:19:49 +0000 2021...
# 3    {'created_at': 'Mon Nov 01 03:19:50 +0000 2021...
# 4    {'created_at': 'Mon Nov 01 03:20:34 +0000 2021...
# ..                                                 ...
# 521  {'created_at': 'Tue Nov 30 21:40:10 +0000 2021...
# 522  {'created_at': 'Tue Nov 30 23:18:44 +0000 2021...
# 523  {'created_at': 'Tue Nov 30 23:20:39 +0000 2021...
# 524  {'created_at': 'Tue Nov 30 23:27:09 +0000 2021...
# 525  {'created_at': 'Tue Nov 30 23:37:22 +0000 2021...
#
# [526 rows x 1 columns]

# %%
for tweet in tweets:
    print(tweet[0])
# Out:
# {'created_at': 'Mon Nov 01 02:02:27 +0000 2021', 'text': '@mishacollins', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'und', 'timestamp_ms': '1635732147661'}
# {'created_at': 'Mon Nov 01 03:19:41 +0000 2021', 'text': '@mishacollins @vic_righthand SIR', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'und', 'timestamp_ms': '1635736781657'}
# {'created_at': 'Mon Nov 01 03:19:49 +0000 2021', 'text': 'RT @mishacollins: Rough day...\n\n@vic_righthand https://t.co/mLb7qNgnEi', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635736789661'}
# {'created_at': 'Mon Nov 01 03:19:50 +0000 2021', 'text': 'RT @mishacollins: Rough day...\n\n@vic_righthand https://t.co/mLb7qNgnEi', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635736790663'}
# {'created_at': 'Mon Nov 01 03:20:34 +0000 2021', 'text': '@mishacollins @vic_righthand I’m contacting my law team', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635736834658'}
# {'created_at': 'Mon Nov 01 03:20:48 +0000 2021', 'text': '@mishacollins @vic_righthand uh. i mean. lookin’ good. ☺️👍🏻', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635736848665'}
# {'created_at': 'Mon Nov 01 03:23:05 +0000 2021', 'text': '@mishacollins @vic_righthand bro me', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635736985666'}
# {'created_at': 'Mon Nov 01 03:25:11 +0000 2021', 'text': 'RT @SoldierTheBoys: two pretty best friends\n@JensenAckles @mishacollins https://t.co/h1C3wTaHJw', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635737111660'}
# {'created_at': 'Mon Nov 01 03:27:47 +0000 2021', 'text': '@Tori658 @FaceMcnerd @mishacollins @vic_righthand Nope, my eye went immediately to it, even on the "wrong" arm.😳😲', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635737267657'}
# {'created_at': 'Mon Nov 01 03:33:55 +0000 2021', 'text': 'RT @mishacollins: Rough day...\n\n@vic_righthand https://t.co/mLb7qNgnEi', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635737635664'}
# {'created_at': 'Mon Nov 01 03:40:05 +0000 2021', 'text': 'RT @mishacollins: Rough day...\n\n@vic_righthand https://t.co/mLb7qNgnEi', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635738005664'}
# {'created_at': 'Mon Nov 01 03:46:13 +0000 2021', 'text': '@proCasDeanating @mishacollins @vic_righthand PLEASE', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635738373663'}
# {'created_at': 'Mon Nov 01 03:50:05 +0000 2021', 'text': '@mishacollins @vic_righthand You got a little something on your face lol', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635738605657'}
# {'created_at': 'Mon Nov 01 03:53:18 +0000 2021', 'text': 'RT @mishacollins: Rough day...\n\n@vic_righthand https://t.co/mLb7qNgnEi', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635738798657'}
# {'created_at': 'Mon Nov 01 04:00:37 +0000 2021', 'text': "RT @SoldierTheBoys: In honor of #Halloween2021, here's a GIF of three SPN cosplayers @JensenAckles @mishacollins @jarpad https://t.co/8Mrum…", 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635739237657'}
# {'created_at': 'Mon Nov 01 04:06:16 +0000 2021', 'text': '@mishacollins @vic_righthand Damn! You still look hot as hell as a zombie! 🤩😍', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635739576661'}
# {'created_at': 'Mon Nov 01 04:07:57 +0000 2021', 'text': 'Life is always going to keep coming at you from all directions. These are good reminders, and poems such as ‘Downpour’ are spot on. Thank you for your words @mishacollins . It’s nice not to feel alone or hopeless. #SomeThingsIStillCantTellYou https://t.co/JYNV3VGEEC https://t.co/wOXT5KxfEh', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635739677666'}
# {'created_at': 'Mon Nov 01 06:34:39 +0000 2021', 'text': '@CasGirl_Sheha @mishacollins @strandbookstore yayy you got your book! Also cute meow meow.', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635748479665'}
# {'created_at': 'Mon Nov 01 08:32:12 +0000 2021', 'text': 'RT @mishacollins: Rough day...\n\n@vic_righthand https://t.co/mLb7qNgnEi', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635755532661'}
# {'created_at': 'Mon Nov 01 10:49:30 +0000 2021', 'text': 'RT @FaceMcnerd: @eldestdaughterr @mishacollins @vic_righthand PLEASE TELL ME YOU SEE IT\n\nITS A FUCKING HANDPRINT\n\nI AM HAVING PROFOUND THOU…', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635763770664'}
# {'created_at': 'Mon Nov 01 10:58:00 +0000 2021', 'text': 'RT @mishacollins: Rough day...\n\n@vic_righthand https://t.co/mLb7qNgnEi', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635764280666'}
# {'created_at': 'Mon Nov 01 11:04:27 +0000 2021', 'text': 'Enjoy the Momento Con 2021 Misha Collins Q&amp;A Panel recorded on Saturday, 9/4/21, at the David Lawrence Convention Center in Pittsburgh, PA. @mishacollins \n\nFind out more about our upcoming events here: \nhttps://t.co/i3wbDbHpXW\n\nhttps://t.co/5DROZP0Vrm', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635764667663'}
# {'created_at': 'Mon Nov 01 11:29:16 +0000 2021', 'text': '@mishacollins @vic_righthand Excuse me sir, you got a little ketchup on you…😜🎃', 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635766156659'}
# {'created_at': 'Mon Nov 01 11:49:24 +0000 2021', 'text': 'RT @mishacollins: Rough day...\n\n@vic_righthand https://t.co/mLb7qNgnEi', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635767364658'}
# {'created_at': 'Mon Nov 01 13:36:41 +0000 2021', 'text': 'RT @mishacollins: Rough day...\n\n@vic_righthand https://t.co/mLb7qNgnEi', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635773801658'}
# {'created_at': 'Mon Nov 01 15:39:47 +0000 2021', 'text': 'RT @mishacollins: Rough day...\n\n@vic_righthand https://t.co/mLb7qNgnEi', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635781187658'}
# {'created_at': 'Mon Nov 01 16:12:48 +0000 2021', 'text': 'RT @mishacollins: Rough day...\n\n@vic_righthand https://t.co/mLb7qNgnEi', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635783168660'}
# {'created_at': 'Mon Nov 01 16:14:52 +0000 2021', 'text': 'RT @mishacollins: Rough day...\n\n@vic_righthand https://t.co/mLb7qNgnEi', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635783292666'}
# {'created_at': 'Mon Nov 01 17:49:32 +0000 2021', 'text': "@magikandmayhem_ @the_endverse @cptnmidnite @mishacollins @vic_righthand That's Phil?????? 😯😯😯", 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635788972661'}
# {'created_at': 'Mon Nov 01 19:14:47 +0000 2021', 'text': 'RT @omgy_: sério que vontade de morrer @mishacollins faça algo para seus fãs pobres brasileiros https://t.co/DIC3wdZ70r', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'pt', 'timestamp_ms': '1635794087666'}
# {'created_at': 'Mon Nov 01 20:06:36 +0000 2021', 'text': '@mishacollins #SomeThingsIStillCantTellYou book is so good that Emma won’t Part with it even while sleeping . Good thing I have another one all for myself . So we both can cuddle into warm blankets and read on a cold November nicht . Get yours here : https://t.co/wTpBw2TjqQ https://t.co/MN0SIrawNq', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635797196666'}
# {'created_at': 'Mon Nov 01 20:31:47 +0000 2021', 'text': 'RT @soshisalt: Ooo, \u2066@mishacollins\u2069 new show is now active on \u2066@instagram\u2069!  https://t.co/3iOkv0LOrT', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635798707659'}
# {'created_at': 'Mon Nov 01 20:41:04 +0000 2021', 'text': "There's something about Misha Collins running that I find very entertaining", 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635799264660'}
# {'created_at': 'Mon Nov 01 20:48:29 +0000 2021', 'text': 'RT @Roadfood123: Have you heard? Our brand new show, ROADFOOD with host @mishacollins is coming November 27th to PBS!!!\nSee behind the scen…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635799709660'}
# {'created_at': 'Mon Nov 01 21:00:00 +0000 2021', 'text': 'Ep.286 — 13:22 — "Exodus"\n\nhumans: not perfect \nhardwired to fall and then \nthey need a fall guy\n\n@MarkRPellegrino @Alex8Calvert @mishacollins', 'source': '<a href="https://zlappo.com" rel="nofollow">Zlappo.com</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635800400663'}
# {'created_at': 'Mon Nov 01 21:05:37 +0000 2021', 'text': "RT @SuperWiki: Can't wait for @mishacollins new show!", 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635800737659'}
# {'created_at': 'Mon Nov 01 21:15:50 +0000 2021', 'text': 'RT @Roadfood123: Have you heard? Our brand new show, ROADFOOD with host @mishacollins is coming November 27th to PBS!!!\nSee behind the scen…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635801350662'}
# {'created_at': 'Mon Nov 01 21:23:38 +0000 2021', 'text': 'RT @Roadfood123: Have you heard? Our brand new show, ROADFOOD with host @mishacollins is coming November 27th to PBS!!!\nSee behind the scen…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635801818665'}
# {'created_at': 'Mon Nov 01 22:32:07 +0000 2021', 'text': "RT @mishacollins: As a belated trick-or-treat, I'm sneaking more signed books into random Barnes &amp; Noble &amp; Target stores  — check your loca…", 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635805927666'}
# {'created_at': 'Mon Nov 01 22:35:59 +0000 2021', 'text': 'RT @SuperWiki: If @mishacollins was coming to your town, what meal would you share with him?', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635806159657'}
# {'created_at': 'Mon Nov 01 23:42:14 +0000 2021', 'text': 'Signed book to Indonesia!!\n\nI feel like hugged not only by @mishacollins but many others. Thankyou so much for @updatesmisha @ewlyn give chance to people with programs and help us so we could get this beautiful book #SomeThingsIStillCantTellYou \n\nGet it: https://t.co/g0nJJbCiV4 https://t.co/iqcYBtpej8', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1635810134663'}
# ...
# {'created_at': 'Mon Nov 29 23:27:40 +0000 2021', 'text': "RT @CasIsLoved: I'm minding my own business and then I come across a post about how Misha Collins asks homeless people what they need and b…", 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1638228460657'}
# {'created_at': 'Mon Nov 29 23:40:14 +0000 2021', 'text': 'RT @Jenmishs_bitch: normalize simping over a man named Misha Collins', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1638229214657'}
# {'created_at': 'Tue Nov 30 00:25:43 +0000 2021', 'text': "RT @CasIsLoved: I'm minding my own business and then I come across a post about how Misha Collins asks homeless people what they need and b…", 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1638231943662'}
# {'created_at': 'Tue Nov 30 05:27:24 +0000 2021', 'text': "RT @EkaGlzz: #MishaCollins interview P1 \nBack on 2009...I'm not crying🥺...ok I am!🤧 https://t.co/YmmfnZHZdK", 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1638250044658'}
# {'created_at': 'Tue Nov 30 07:08:54 +0000 2021', 'text': '@KaiaPrigmore @MarkRPellegrino @jarpad @JensenAckles @mishacollins @Mark_Sheppard @RuthieConnell That is incredible. Beautiful work of art.', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1638256134665'}
# {'created_at': 'Tue Nov 30 17:38:46 +0000 2021', 'text': 'RT @autisticcastiel: adam fergus as misha collins, a thread https://t.co/w1NxzQeEDj', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1638293926661'}
# {'created_at': 'Tue Nov 30 20:02:12 +0000 2021', 'text': 'My 18 yr old daughter has Tuberous Sclerosis Complex. It caused her to have epilepsy, autism, Neurodevelopmental delay, and cysts and tumors throughout her organ systems including brain, lungs, kidneys, liver and heart. @Stands @RandomActsOrg @mishacollins @tscalliance', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1638302532666'}
# {'created_at': 'Tue Nov 30 20:42:59 +0000 2021', 'text': 'RT @CappysCreations: This fact has always made me happy. Thanks @mishacollins for just existing https://t.co/dGPtfYgNgj', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1638304979660'}
# {'created_at': 'Tue Nov 30 21:40:10 +0000 2021', 'text': 'RT @CreationEnt: Jensen Ackles, Jared Padalecki and Misha Collins headline The Official Supernatural Convention coming to the Bay Area on J…', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1638308410664'}
# {'created_at': 'Tue Nov 30 23:18:44 +0000 2021', 'text': 'RT @mishacollins: I know it’s late in the day on #GivingTuesday, but me &amp; the Padaleckis have conspired to spur your charitable impulses on…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1638314324659'}
# {'created_at': 'Tue Nov 30 23:20:39 +0000 2021', 'text': 'RT @mishacollins: I know it’s late in the day on #GivingTuesday, but me &amp; the Padaleckis have conspired to spur your charitable impulses on…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1638314439658'}
# {'created_at': 'Tue Nov 30 23:27:09 +0000 2021', 'text': '@mishacollins i love you king', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1638314829661'}
# {'created_at': 'Tue Nov 30 23:37:22 +0000 2021', 'text': 'RT @mishacollins: I know it’s late in the day on #GivingTuesday, but me &amp; the Padaleckis have conspired to spur your charitable impulses on…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', '\n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang': 'en', 'timestamp_ms': '1638315442665'}

# %% [markdown]
# df = pd.read_json('file.json', lines = True)
# df = (pd.DataFrame(df['aspect'].values.tolist()).add_prefix('aspect.').join(df.drop('aspect', 1)))

# %%
pd.DataFrame.from_dict(tweet)
# Out:
#                        created_at  \
# 0  Tue Nov 30 23:37:22 +0000 2021
#
#                                                 text  \
# 0  RT @mishacollins: I know it’s late in the day ...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
#
#   \n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang  \
# 0                                                 en
#
#     timestamp_ms
# 0  1638315442665

# %%
df = pd.read_json(files[0], lines=True)
(pd.DataFrame(df[0].values.tolist()).join(df.drop(0, 1)))
# Out:
# C:\Users\Juliet\AppData\Local\Temp\ipykernel_11032\2211459617.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   (pd.DataFrame(df[0].values.tolist()).join(df.drop(0, 1)))
#                          created_at  \
# 0    Mon Nov 01 02:02:27 +0000 2021
# 1    Mon Nov 01 03:19:41 +0000 2021
# 2    Mon Nov 01 03:19:49 +0000 2021
# 3    Mon Nov 01 03:19:50 +0000 2021
# 4    Mon Nov 01 03:20:34 +0000 2021
# ..                              ...
# 521  Tue Nov 30 21:40:10 +0000 2021
# 522  Tue Nov 30 23:18:44 +0000 2021
# 523  Tue Nov 30 23:20:39 +0000 2021
# 524  Tue Nov 30 23:27:09 +0000 2021
# 525  Tue Nov 30 23:37:22 +0000 2021
#
#                                                   text  \
# 0                                        @mishacollins
# 1                     @mishacollins @vic_righthand SIR
# 2    RT @mishacollins: Rough day...\n\n@vic_rightha...
# 3    RT @mishacollins: Rough day...\n\n@vic_rightha...
# 4    @mishacollins @vic_righthand I’m contacting my...
# ..                                                 ...
# 521  RT @CreationEnt: Jensen Ackles, Jared Padaleck...
# 522  RT @mishacollins: I know it’s late in the day ...
# 523  RT @mishacollins: I know it’s late in the day ...
# 524                      @mishacollins i love you king
# 525  RT @mishacollins: I know it’s late in the day ...
#
#                                                 source  \
# 0    <a href="http://twitter.com/download/android" ...
# 1    <a href="http://twitter.com/download/iphone" r...
# 2    <a href="http://twitter.com/download/iphone" r...
# 3    <a href="http://twitter.com/download/android" ...
# 4    <a href="http://twitter.com/download/iphone" r...
# ..                                                 ...
# 521  <a href="https://mobile.twitter.com" rel="nofo...
# 522  <a href="http://twitter.com/download/android" ...
# 523  <a href="http://twitter.com/download/android" ...
# 524  <a href="http://twitter.com/download/iphone" r...
# 525  <a href="http://twitter.com/download/android" ...
#
#     \n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang  \
# 0                                                  und
# 1                                                  und
# 2                                                   en
# 3                                                   en
# 4                                                   en
# ..                                                 ...
# 521                                                 en
# 522                                                 en
# 523                                                 en
# 524                                                 en
# 525                                                 en
#
#       timestamp_ms
# 0    1635732147661
# 1    1635736781657
# 2    1635736789661
# 3    1635736790663
# 4    1635736834658
# ..             ...
# 521  1638308410664
# 522  1638314324659
# 523  1638314439658
# 524  1638314829661
# 525  1638315442665
#
# [526 rows x 5 columns]

# %%
df_list = []
for file in files:
    df_list.append(pd.read_json(file, lines=True))

# %%
df_list
# Out:
# [                                                     0
#  0    {'created_at': 'Mon Nov 01 02:02:27 +0000 2021...
#  1    {'created_at': 'Mon Nov 01 03:19:41 +0000 2021...
#  2    {'created_at': 'Mon Nov 01 03:19:49 +0000 2021...
#  3    {'created_at': 'Mon Nov 01 03:19:50 +0000 2021...
#  4    {'created_at': 'Mon Nov 01 03:20:34 +0000 2021...
#  ..                                                 ...
#  521  {'created_at': 'Tue Nov 30 21:40:10 +0000 2021...
#  522  {'created_at': 'Tue Nov 30 23:18:44 +0000 2021...
#  523  {'created_at': 'Tue Nov 30 23:20:39 +0000 2021...
#  524  {'created_at': 'Tue Nov 30 23:27:09 +0000 2021...
#  525  {'created_at': 'Tue Nov 30 23:37:22 +0000 2021...
#
#  [526 rows x 1 columns],
#                                                       0
#  0    {'created_at': 'Wed Dec 01 00:41:09 +0000 2021...
#  1    {'created_at': 'Wed Dec 01 04:00:35 +0000 2021...
#  2    {'created_at': 'Wed Dec 01 04:26:05 +0000 2021...
#  3    {'created_at': 'Wed Dec 01 12:00:05 +0000 2021...
#  4    {'created_at': 'Wed Dec 01 12:57:19 +0000 2021...
#  ..                                                 ...
#  559  {'created_at': 'Fri Dec 31 19:25:47 +0000 2021...
#  560  {'created_at': 'Fri Dec 31 20:59:34 +0000 2021...
#  561  {'created_at': 'Fri Dec 31 22:10:07 +0000 2021...
#  562  {'created_at': 'Fri Dec 31 22:13:05 +0000 2021...
#  563  {'created_at': 'Fri Dec 31 22:17:11 +0000 2021...
#
#  [564 rows x 1 columns],
#                                                       0
#  0    {'created_at': 'Sat Jan 01 01:44:11 +0000 2022...
#  1    {'created_at': 'Sat Jan 01 04:43:55 +0000 2022...
#  2    {'created_at': 'Sat Jan 01 05:29:29 +0000 2022...
#  3    {'created_at': 'Sat Jan 01 06:03:03 +0000 2022...
#  4    {'created_at': 'Sat Jan 01 06:11:50 +0000 2022...
#  ..                                                 ...
#  531  {'created_at': 'Mon Jan 31 22:16:44 +0000 2022...
#  532  {'created_at': 'Mon Jan 31 22:44:05 +0000 2022...
#  533  {'created_at': 'Mon Jan 31 23:00:59 +0000 2022...
#  534  {'created_at': 'Mon Jan 31 23:24:55 +0000 2022...
#  535  {'created_at': 'Mon Jan 31 23:26:54 +0000 2022...
#
#  [536 rows x 1 columns],
#                                                       0
#  0    {'created_at': 'Tue Feb 01 00:00:51 +0000 2022...
#  1    {'created_at': 'Tue Feb 01 00:17:51 +0000 2022...
#  2    {'created_at': 'Tue Feb 01 00:46:16 +0000 2022...
#  3    {'created_at': 'Tue Feb 01 00:57:02 +0000 2022...
#  4    {'created_at': 'Tue Feb 01 02:12:58 +0000 2022...
#  ..                                                 ...
#  727  {'created_at': 'Mon Feb 28 21:11:32 +0000 2022...
#  728  {'created_at': 'Mon Feb 28 21:19:15 +0000 2022...
#  729  {'created_at': 'Mon Feb 28 22:37:31 +0000 2022...
#  730  {'created_at': 'Mon Feb 28 22:51:50 +0000 2022...
#  731  {'created_at': 'Mon Feb 28 23:34:33 +0000 2022...
#
#  [732 rows x 1 columns],
#                                                       0
#  0    {'created_at': 'Tue Mar 01 03:07:47 +0000 2022...
#  1    {'created_at': 'Tue Mar 01 04:15:17 +0000 2022...
#  2    {'created_at': 'Tue Mar 01 04:38:48 +0000 2022...
#  3    {'created_at': 'Tue Mar 01 07:15:53 +0000 2022...
#  4    {'created_at': 'Tue Mar 01 13:26:06 +0000 2022...
#  ..                                                 ...
#  839  {'created_at': 'Thu Mar 31 21:57:04 +0000 2022...
#  840  {'created_at': 'Thu Mar 31 22:14:25 +0000 2022...
#  841  {'created_at': 'Thu Mar 31 22:38:53 +0000 2022...
#  842  {'created_at': 'Thu Mar 31 22:43:30 +0000 2022...
#  843  {'created_at': 'Thu Mar 31 23:11:00 +0000 2022...
#
#  [844 rows x 1 columns],
#                                                        0
#  0     {'created_at': 'Fri Apr 01 03:01:48 +0000 2022...
#  1     {'created_at': 'Fri Apr 01 08:02:00 +0000 2022...
#  2     {'created_at': 'Fri Apr 01 08:22:22 +0000 2022...
#  3     {'created_at': 'Fri Apr 01 11:04:40 +0000 2022...
#  4     {'created_at': 'Fri Apr 01 12:46:37 +0000 2022...
#  ...                                                 ...
#  1341  {'created_at': 'Sat Apr 30 14:12:47 +0000 2022...
#  1342  {'created_at': 'Sat Apr 30 19:16:10 +0000 2022...
#  1343  {'created_at': 'Sat Apr 30 23:11:53 +0000 2022...
#  1344  {'created_at': 'Sat Apr 30 23:25:34 +0000 2022...
#  1345  {'created_at': 'Sat Apr 30 23:47:43 +0000 2022...
#
#  [1346 rows x 1 columns],
#                                                       0
#  0    {'created_at': 'Sun May 01 00:32:59 +0000 2022...
#  1    {'created_at': 'Sun May 01 02:17:28 +0000 2022...
#  2    {'created_at': 'Sun May 01 06:01:04 +0000 2022...
#  3    {'created_at': 'Sun May 01 12:57:51 +0000 2022...
#  4    {'created_at': 'Sun May 01 18:49:18 +0000 2022...
#  ..                                                 ...
#  604  {'created_at': 'Tue May 31 22:10:10 +0000 2022...
#  605  {'created_at': 'Tue May 31 22:34:02 +0000 2022...
#  606  {'created_at': 'Tue May 31 23:01:02 +0000 2022...
#  607  {'created_at': 'Tue May 31 23:07:04 +0000 2022...
#  608  {'created_at': 'Tue May 31 23:25:35 +0000 2022...
#
#  [609 rows x 1 columns],
#                                                       0
#  0    {'created_at': 'Wed Jun 01 00:29:29 +0000 2022...
#  1    {'created_at': 'Wed Jun 01 01:13:32 +0000 2022...
#  2    {'created_at': 'Wed Jun 01 03:05:35 +0000 2022...
#  3    {'created_at': 'Wed Jun 01 04:15:27 +0000 2022...
#  4    {'created_at': 'Wed Jun 01 05:29:30 +0000 2022...
#  ..                                                 ...
#  391  {'created_at': 'Thu Jun 30 03:21:28 +0000 2022...
#  392  {'created_at': 'Thu Jun 30 05:45:19 +0000 2022...
#  393  {'created_at': 'Thu Jun 30 10:36:00 +0000 2022...
#  394  {'created_at': 'Thu Jun 30 13:36:58 +0000 2022...
#  395  {'created_at': 'Thu Jun 30 20:21:43 +0000 2022...
#
#  [396 rows x 1 columns],
#                                                       0
#  0    {'created_at': 'Fri Jul 01 00:33:52 +0000 2022...
#  1    {'created_at': 'Fri Jul 01 00:33:59 +0000 2022...
#  2    {'created_at': 'Fri Jul 01 00:34:35 +0000 2022...
#  3    {'created_at': 'Fri Jul 01 00:35:41 +0000 2022...
#  4    {'created_at': 'Fri Jul 01 00:37:23 +0000 2022...
#  ..                                                 ...
#  410  {'created_at': 'Sun Jul 31 21:58:10 +0000 2022...
#  411  {'created_at': 'Sun Jul 31 22:21:55 +0000 2022...
#  412  {'created_at': 'Sun Jul 31 22:25:44 +0000 2022...
#  413  {'created_at': 'Sun Jul 31 23:14:07 +0000 2022...
#  414  {'created_at': 'Sun Jul 31 23:28:50 +0000 2022...
#
#  [415 rows x 1 columns],
#                                                       0
#  0    {'created_at': 'Mon Aug 01 00:15:06 +0000 2022...
#  1    {'created_at': 'Mon Aug 01 00:45:12 +0000 2022...
#  2    {'created_at': 'Mon Aug 01 01:21:20 +0000 2022...
#  3    {'created_at': 'Mon Aug 01 01:23:31 +0000 2022...
#  4    {'created_at': 'Mon Aug 01 01:24:05 +0000 2022...
#  ..                                                 ...
#  557  {'created_at': 'Wed Aug 31 20:14:13 +0000 2022...
#  558  {'created_at': 'Wed Aug 31 21:17:39 +0000 2022...
#  559  {'created_at': 'Wed Aug 31 21:47:46 +0000 2022...
#  560  {'created_at': 'Wed Aug 31 23:05:19 +0000 2022...
#  561  {'created_at': 'Wed Aug 31 23:45:31 +0000 2022...
#
#  [562 rows x 1 columns],
#                                                       0
#  0    {'created_at': 'Thu Sep 01 06:48:52 +0000 2022...
#  1    {'created_at': 'Thu Sep 01 07:11:13 +0000 2022...
#  2    {'created_at': 'Thu Sep 01 08:26:18 +0000 2022...
#  3    {'created_at': 'Thu Sep 01 10:01:08 +0000 2022...
#  4    {'created_at': 'Thu Sep 01 10:27:16 +0000 2022...
#  ..                                                 ...
#  865  {'created_at': 'Fri Sep 30 12:39:17 +0000 2022...
#  866  {'created_at': 'Fri Sep 30 15:04:22 +0000 2022...
#  867  {'created_at': 'Fri Sep 30 17:43:25 +0000 2022...
#  868  {'created_at': 'Fri Sep 30 18:55:15 +0000 2022...
#  869  {'created_at': 'Fri Sep 30 23:55:45 +0000 2022...
#
#  [870 rows x 1 columns],
#                                                       0
#  0    {'created_at': 'Sat Oct 01 03:44:19 +0000 2022...
#  1    {'created_at': 'Sat Oct 01 03:48:05 +0000 2022...
#  2    {'created_at': 'Sat Oct 01 06:39:46 +0000 2022...
#  3    {'created_at': 'Sat Oct 01 07:43:58 +0000 2022...
#  4    {'created_at': 'Sat Oct 01 14:53:20 +0000 2022...
#  ..                                                 ...
#  597  {'created_at': 'Mon Oct 31 19:40:13 +0000 2022...
#  598  {'created_at': 'Mon Oct 31 20:28:32 +0000 2022...
#  599  {'created_at': 'Mon Oct 31 21:29:44 +0000 2022...
#  600  {'created_at': 'Mon Oct 31 21:53:55 +0000 2022...
#  601  {'created_at': 'Mon Oct 31 23:13:22 +0000 2022...
#
#  [602 rows x 1 columns],
#                                                       0
#  0    {'created_at': 'Tue Nov 01 00:06:25 +0000 2022...
#  1    {'created_at': 'Tue Nov 01 00:26:14 +0000 2022...
#  2    {'created_at': 'Tue Nov 01 00:33:24 +0000 2022...
#  3    {'created_at': 'Tue Nov 01 01:08:37 +0000 2022...
#  4    {'created_at': 'Tue Nov 01 01:18:08 +0000 2022...
#  ..                                                 ...
#  684  {'created_at': 'Tue Nov 22 16:25:31 +0000 2022...
#  685  {'created_at': 'Tue Nov 22 17:22:47 +0000 2022...
#  686  {'created_at': 'Tue Nov 22 18:02:34 +0000 2022...
#  687  {'created_at': 'Tue Nov 22 20:01:11 +0000 2022...
#  688  {'created_at': 'Tue Nov 22 22:01:25 +0000 2022...
#
#  [689 rows x 1 columns]]

# %%
df = pd.concat(df_list, ignore_index=True)

# %%
df
# Out:
#                                                       0
# 0     {'created_at': 'Mon Nov 01 02:02:27 +0000 2021...
# 1     {'created_at': 'Mon Nov 01 03:19:41 +0000 2021...
# 2     {'created_at': 'Mon Nov 01 03:19:49 +0000 2021...
# 3     {'created_at': 'Mon Nov 01 03:19:50 +0000 2021...
# 4     {'created_at': 'Mon Nov 01 03:20:34 +0000 2021...
# ...                                                 ...
# 8686  {'created_at': 'Tue Nov 22 16:25:31 +0000 2022...
# 8687  {'created_at': 'Tue Nov 22 17:22:47 +0000 2022...
# 8688  {'created_at': 'Tue Nov 22 18:02:34 +0000 2022...
# 8689  {'created_at': 'Tue Nov 22 20:01:11 +0000 2022...
# 8690  {'created_at': 'Tue Nov 22 22:01:25 +0000 2022...
#
# [8691 rows x 1 columns]

# %%
df_tweets = pd.DataFrame(df[0].values.tolist()).join(df.drop(0, 1))
# Out:
# C:\Users\Juliet\AppData\Local\Temp\ipykernel_11032\569452358.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_tweets = pd.DataFrame(df[0].values.tolist()).join(df.drop(0, 1))

# %%
df_tweets
# Out:
#                           created_at  \
# 0     Mon Nov 01 02:02:27 +0000 2021
# 1     Mon Nov 01 03:19:41 +0000 2021
# 2     Mon Nov 01 03:19:49 +0000 2021
# 3     Mon Nov 01 03:19:50 +0000 2021
# 4     Mon Nov 01 03:20:34 +0000 2021
# ...                              ...
# 8686  Tue Nov 22 16:25:31 +0000 2022
# 8687  Tue Nov 22 17:22:47 +0000 2022
# 8688  Tue Nov 22 18:02:34 +0000 2022
# 8689  Tue Nov 22 20:01:11 +0000 2022
# 8690  Tue Nov 22 22:01:25 +0000 2022
#
#                                                    text  \
# 0                                         @mishacollins
# 1                      @mishacollins @vic_righthand SIR
# 2     RT @mishacollins: Rough day...\n\n@vic_rightha...
# 3     RT @mishacollins: Rough day...\n\n@vic_rightha...
# 4     @mishacollins @vic_righthand I’m contacting my...
# ...                                                 ...
# 8686  RT @JensenPadaYU: Have a good night. Tomorrow ...
# 8687  RT @embersgrimm: a show about gay nuns is gett...
# 8688  @GISH @Legacy_of_War @mishacollins @charliecap...
# 8689  RT @kanstans: so far we got snooki, misha coll...
# 8690  @NewsAckles @JensenAckles @jarpad @mishacollin...
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/android" ...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/android" ...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 8686  <a href="http://twitter.com/download/iphone" r...
# 8687  <a href="http://twitter.com/download/android" ...
# 8688  <a href="http://twitter.com/download/iphone" r...
# 8689  <a href="http://twitter.com/download/iphone" r...
# 8690  <a href="https://mobile.twitter.com" rel="nofo...
#
#      \n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang  \
# 0                                                   und
# 1                                                   und
# 2                                                    en
# 3                                                    en
# 4                                                    en
# ...                                                 ...
# 8686                                                 en
# 8687                                                 en
# 8688                                                 en
# 8689                                                 en
# 8690                                                 en
#
#        timestamp_ms
# 0     1635732147661
# 1     1635736781657
# 2     1635736789661
# 3     1635736790663
# 4     1635736834658
# ...             ...
# 8686  1669134331665
# 8687  1669137767661
# 8688  1669140154664
# 8689  1669147271664
# 8690  1669154485658
#
# [8691 rows x 5 columns]

# %%
df_tweets = df_tweets.drop('source', axis=1)

# %%
df_tweets.head()
# Out:
#                        created_at  \
# 0  Mon Nov 01 02:02:27 +0000 2021
# 1  Mon Nov 01 03:19:41 +0000 2021
# 2  Mon Nov 01 03:19:49 +0000 2021
# 3  Mon Nov 01 03:19:50 +0000 2021
# 4  Mon Nov 01 03:20:34 +0000 2021
#
#                                                 text  \
# 0                                      @mishacollins
# 1                   @mishacollins @vic_righthand SIR
# 2  RT @mishacollins: Rough day...\n\n@vic_rightha...
# 3  RT @mishacollins: Rough day...\n\n@vic_rightha...
# 4  @mishacollins @vic_righthand I’m contacting my...
#
#   \n            "user": {\n                "id": tweet_user_id,\n                "name": tweet_user_name,\n                "location": tweet_user_location,\n                "url": tweet_user_url,\n                "description": tweet_user_description,\n                "verified": tweet_user_verified,\n                "followers_count": tweet_user_follower_count,\n                "friends_count": tweet_user_friends_count,\n                "favourites_count": tweet_user_favourites_count,\n                "statuses_count": tweet_user_statuses_count,\n                "created_at": tweet_user_created_at,\n                "utc_offset": tweet_user_utc_offset,\n                "time_zone": tweet_user_timezone,\n                "geo_enabled": tweet_user_geo_enabled,\n                "lang": tweet_user_language,\n                },\n            lang  \
# 0                                                und
# 1                                                und
# 2                                                 en
# 3                                                 en
# 4                                                 en
#
#     timestamp_ms
# 0  1635732147661
# 1  1635736781657
# 2  1635736789661
# 3  1635736790663
# 4  1635736834658

# %%
df_tweets.rename(columns={df_tweets.columns[2]:'lang'}, inplace=True)

# %%
df_tweets.head()
# Out:
#                        created_at  \
# 0  Mon Nov 01 02:02:27 +0000 2021
# 1  Mon Nov 01 03:19:41 +0000 2021
# 2  Mon Nov 01 03:19:49 +0000 2021
# 3  Mon Nov 01 03:19:50 +0000 2021
# 4  Mon Nov 01 03:20:34 +0000 2021
#
#                                                 text lang   timestamp_ms
# 0                                      @mishacollins  und  1635732147661
# 1                   @mishacollins @vic_righthand SIR  und  1635736781657
# 2  RT @mishacollins: Rough day...\n\n@vic_rightha...   en  1635736789661
# 3  RT @mishacollins: Rough day...\n\n@vic_rightha...   en  1635736790663
# 4  @mishacollins @vic_righthand I’m contacting my...   en  1635736834658

# %%
df_tweets = df_tweets[df_tweets['lang'] =='en']
df_tweets
# Out:
#                           created_at  \
# 2     Mon Nov 01 03:19:49 +0000 2021
# 3     Mon Nov 01 03:19:50 +0000 2021
# 4     Mon Nov 01 03:20:34 +0000 2021
# 5     Mon Nov 01 03:20:48 +0000 2021
# 6     Mon Nov 01 03:23:05 +0000 2021
# ...                              ...
# 8686  Tue Nov 22 16:25:31 +0000 2022
# 8687  Tue Nov 22 17:22:47 +0000 2022
# 8688  Tue Nov 22 18:02:34 +0000 2022
# 8689  Tue Nov 22 20:01:11 +0000 2022
# 8690  Tue Nov 22 22:01:25 +0000 2022
#
#                                                    text lang   timestamp_ms
# 2     RT @mishacollins: Rough day...\n\n@vic_rightha...   en  1635736789661
# 3     RT @mishacollins: Rough day...\n\n@vic_rightha...   en  1635736790663
# 4     @mishacollins @vic_righthand I’m contacting my...   en  1635736834658
# 5     @mishacollins @vic_righthand uh. i mean. looki...   en  1635736848665
# 6                   @mishacollins @vic_righthand bro me   en  1635736985666
# ...                                                 ...  ...            ...
# 8686  RT @JensenPadaYU: Have a good night. Tomorrow ...   en  1669134331665
# 8687  RT @embersgrimm: a show about gay nuns is gett...   en  1669137767661
# 8688  @GISH @Legacy_of_War @mishacollins @charliecap...   en  1669140154664
# 8689  RT @kanstans: so far we got snooki, misha coll...   en  1669147271664
# 8690  @NewsAckles @JensenAckles @jarpad @mishacollin...   en  1669154485658
#
# [7280 rows x 4 columns]

# %%
df_tweets = df_tweets[~df_tweets['text'].str.startswith('RT')] #remove retweets
df_tweets
# Out:
#                           created_at  \
# 4     Mon Nov 01 03:20:34 +0000 2021
# 5     Mon Nov 01 03:20:48 +0000 2021
# 6     Mon Nov 01 03:23:05 +0000 2021
# 8     Mon Nov 01 03:27:47 +0000 2021
# 11    Mon Nov 01 03:46:13 +0000 2021
# ...                              ...
# 8682  Mon Nov 21 14:03:13 +0000 2022
# 8683  Mon Nov 21 14:19:40 +0000 2022
# 8684  Mon Nov 21 16:05:37 +0000 2022
# 8688  Tue Nov 22 18:02:34 +0000 2022
# 8690  Tue Nov 22 22:01:25 +0000 2022
#
#                                                    text lang   timestamp_ms
# 4     @mishacollins @vic_righthand I’m contacting my...   en  1635736834658
# 5     @mishacollins @vic_righthand uh. i mean. looki...   en  1635736848665
# 6                   @mishacollins @vic_righthand bro me   en  1635736985666
# 8     @Tori658 @FaceMcnerd @mishacollins @vic_righth...   en  1635737267657
# 11    @proCasDeanating @mishacollins @vic_righthand ...   en  1635738373663
# ...                                                 ...  ...            ...
# 8682    @mishacollins  Charmed! https://t.co/ro5R6Bi51x   en  1669039393660
# 8683  @mishacollins @JensenAckles pick up your trash...   en  1669040380661
# 8684  Joke 439.@mishacollins \n\nHave a wonderful da...   en  1669046737658
# 8688  @GISH @Legacy_of_War @mishacollins @charliecap...   en  1669140154664
# 8690  @NewsAckles @JensenAckles @jarpad @mishacollin...   en  1669154485658
#
# [2272 rows x 4 columns]

# %%
# taken from Muhammad Iqbal's Tutorial_7 (part II) on imdb film reviews + stackoverflow https://stackoverflow.com/a/8377440/5762852

import re
def preprocessor(text):
    text = re.sub('(#[A-Za-z0-9]+)|(@[A-Za-z0-9_]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', text)
    emoticons = re.findall('(?::|;|=)(?:-)?(?:\)|\(|D|P)',
                           text)
    text = (re.sub('[\W]+', ' ', text.lower()) +
            ' '.join(emoticons).replace('-', ''))
    return text

# %%
df_tweets.iloc[789, 1]
# Out:
# '.@mishacollins raising money for Ukraine  #SPNLV https://t.co/Q5V5LcVMXO'

# %%
preprocessor(df_tweets.iloc[789, 1]) #removed usernames hashtag and link
# Out:
# ' raising money for ukraine '

# %%
df_tweets.iloc[189, 1]
# Out:
# '@jules_laufeyson @updatesmisha @mishacollins 🤩 sealed with a wink'

# %%
preprocessor(df_tweets.iloc[189, 1]) #also removes emoji
# Out:
# ' sealed with a wink'

# %%
df_tweets['preprocessed'] = df_tweets['text'].apply(lambda x : preprocessor(x))
# Out:
# C:\Users\Juliet\AppData\Local\Temp\ipykernel_11032\980936104.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tweets['preprocessed'] = df_tweets['text'].apply(lambda x : preprocessor(x))

# %%
df_tweets
# Out:
#                           created_at  \
# 4     Mon Nov 01 03:20:34 +0000 2021
# 5     Mon Nov 01 03:20:48 +0000 2021
# 6     Mon Nov 01 03:23:05 +0000 2021
# 8     Mon Nov 01 03:27:47 +0000 2021
# 11    Mon Nov 01 03:46:13 +0000 2021
# ...                              ...
# 8682  Mon Nov 21 14:03:13 +0000 2022
# 8683  Mon Nov 21 14:19:40 +0000 2022
# 8684  Mon Nov 21 16:05:37 +0000 2022
# 8688  Tue Nov 22 18:02:34 +0000 2022
# 8690  Tue Nov 22 22:01:25 +0000 2022
#
#                                                    text lang   timestamp_ms  \
# 4     @mishacollins @vic_righthand I’m contacting my...   en  1635736834658
# 5     @mishacollins @vic_righthand uh. i mean. looki...   en  1635736848665
# 6                   @mishacollins @vic_righthand bro me   en  1635736985666
# 8     @Tori658 @FaceMcnerd @mishacollins @vic_righth...   en  1635737267657
# 11    @proCasDeanating @mishacollins @vic_righthand ...   en  1635738373663
# ...                                                 ...  ...            ...
# 8682    @mishacollins  Charmed! https://t.co/ro5R6Bi51x   en  1669039393660
# 8683  @mishacollins @JensenAckles pick up your trash...   en  1669040380661
# 8684  Joke 439.@mishacollins \n\nHave a wonderful da...   en  1669046737658
# 8688  @GISH @Legacy_of_War @mishacollins @charliecap...   en  1669140154664
# 8690  @NewsAckles @JensenAckles @jarpad @mishacollin...   en  1669154485658
#
#                                            preprocessed
# 4                            i m contacting my law team
# 5                                uh i mean lookin good
# 6                                                bro me
# 8      nope my eye went immediately to it even on th...
# 11                                               please
# ...                                                 ...
# 8682                                           charmed
# 8683                       pick up your trash challenge
# 8684               joke 439 have a wonderful day misha
# 8688                               sock monkey hat ftw
# 8690                   look at the smoulder on ja phew
#
# [2272 rows x 5 columns]

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Juliet\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Juliet\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
df_tweets.iloc[789, 4] #just to remind you what it said
# Out:
# ' raising money for ukraine '

# %%
from nltk.stem.wordnet import WordNetLemmatizer

# Create an initialise an object 'lem' by calling a method WordNetLemmatizer()
lem = WordNetLemmatizer()

# Display the Lemmatized and stemmed words
print("Lemmatized Words:", [lem.lemmatize(word, "v") for word in df_tweets.iloc[789, 4].split()])
# Out:
# Lemmatized Words: ['raise', 'money', 'for', 'ukraine']

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Juliet\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# Load the stop words
stop = stopwords.words("english")

# Display the stop words
print(stop)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
def clean(sentence, stop_words):
    return ' '.join([WordNetLemmatizer().lemmatize(word, 'v') for word in sentence.split() if (word not in stop_words)])

# %%
df_tweets['lemma stop'] = df_tweets['preprocessed'].apply(lambda x : clean(x, stop))
# Out:
# C:\Users\Juliet\AppData\Local\Temp\ipykernel_11032\895061617.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tweets['lemma stop'] = df_tweets['preprocessed'].apply(lambda x : clean(x, stop))

# %%
df_tweets
# Out:
#                           created_at  \
# 4     Mon Nov 01 03:20:34 +0000 2021
# 5     Mon Nov 01 03:20:48 +0000 2021
# 6     Mon Nov 01 03:23:05 +0000 2021
# 8     Mon Nov 01 03:27:47 +0000 2021
# 11    Mon Nov 01 03:46:13 +0000 2021
# ...                              ...
# 8682  Mon Nov 21 14:03:13 +0000 2022
# 8683  Mon Nov 21 14:19:40 +0000 2022
# 8684  Mon Nov 21 16:05:37 +0000 2022
# 8688  Tue Nov 22 18:02:34 +0000 2022
# 8690  Tue Nov 22 22:01:25 +0000 2022
#
#                                                    text lang   timestamp_ms  \
# 4     @mishacollins @vic_righthand I’m contacting my...   en  1635736834658
# 5     @mishacollins @vic_righthand uh. i mean. looki...   en  1635736848665
# 6                   @mishacollins @vic_righthand bro me   en  1635736985666
# 8     @Tori658 @FaceMcnerd @mishacollins @vic_righth...   en  1635737267657
# 11    @proCasDeanating @mishacollins @vic_righthand ...   en  1635738373663
# ...                                                 ...  ...            ...
# 8682    @mishacollins  Charmed! https://t.co/ro5R6Bi51x   en  1669039393660
# 8683  @mishacollins @JensenAckles pick up your trash...   en  1669040380661
# 8684  Joke 439.@mishacollins \n\nHave a wonderful da...   en  1669046737658
# 8688  @GISH @Legacy_of_War @mishacollins @charliecap...   en  1669140154664
# 8690  @NewsAckles @JensenAckles @jarpad @mishacollin...   en  1669154485658
#
#                                            preprocessed  \
# 4                            i m contacting my law team
# 5                                uh i mean lookin good
# 6                                                bro me
# 8      nope my eye went immediately to it even on th...
# 11                                               please
# ...                                                 ...
# 8682                                           charmed
# 8683                       pick up your trash challenge
# 8684               joke 439 have a wonderful day misha
# 8688                               sock monkey hat ftw
# 8690                   look at the smoulder on ja phew
#
#                                   lemma stop
# 4                           contact law team
# 5                        uh mean lookin good
# 6                                        bro
# 8     nope eye go immediately even wrong arm
# 11                                    please
# ...                                      ...
# 8682                                   charm
# 8683                    pick trash challenge
# 8684            joke 439 wonderful day misha
# 8688                     sock monkey hat ftw
# 8690                   look smoulder ja phew
#
# [2272 rows x 6 columns]

# %%
df_tweets.to_csv('cleaned_tweets.csv')

# %% [markdown]
# ## Sentiment Analysis

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

#nltk.download('vader_lexicon')
vader = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Juliet\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
df_tweets['compound'] = df_tweets['lemma stop'].apply(lambda x : vader.polarity_scores(x)['compound'])
# Out:
# C:\Users\Juliet\AppData\Local\Temp\ipykernel_11032\583802390.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tweets['compound'] = df_tweets['lemma stop'].apply(lambda x : vader.polarity_scores(x)['compound'])

# %%
df_tweets
# Out:
#                           created_at  \
# 4     Mon Nov 01 03:20:34 +0000 2021
# 5     Mon Nov 01 03:20:48 +0000 2021
# 6     Mon Nov 01 03:23:05 +0000 2021
# 8     Mon Nov 01 03:27:47 +0000 2021
# 11    Mon Nov 01 03:46:13 +0000 2021
# ...                              ...
# 8682  Mon Nov 21 14:03:13 +0000 2022
# 8683  Mon Nov 21 14:19:40 +0000 2022
# 8684  Mon Nov 21 16:05:37 +0000 2022
# 8688  Tue Nov 22 18:02:34 +0000 2022
# 8690  Tue Nov 22 22:01:25 +0000 2022
#
#                                                    text lang   timestamp_ms  \
# 4     @mishacollins @vic_righthand I’m contacting my...   en  1635736834658
# 5     @mishacollins @vic_righthand uh. i mean. looki...   en  1635736848665
# 6                   @mishacollins @vic_righthand bro me   en  1635736985666
# 8     @Tori658 @FaceMcnerd @mishacollins @vic_righth...   en  1635737267657
# 11    @proCasDeanating @mishacollins @vic_righthand ...   en  1635738373663
# ...                                                 ...  ...            ...
# 8682    @mishacollins  Charmed! https://t.co/ro5R6Bi51x   en  1669039393660
# 8683  @mishacollins @JensenAckles pick up your trash...   en  1669040380661
# 8684  Joke 439.@mishacollins \n\nHave a wonderful da...   en  1669046737658
# 8688  @GISH @Legacy_of_War @mishacollins @charliecap...   en  1669140154664
# 8690  @NewsAckles @JensenAckles @jarpad @mishacollin...   en  1669154485658
#
#                                            preprocessed  \
# 4                            i m contacting my law team
# 5                                uh i mean lookin good
# 6                                                bro me
# 8      nope my eye went immediately to it even on th...
# 11                                               please
# ...                                                 ...
# 8682                                           charmed
# 8683                       pick up your trash challenge
# 8684               joke 439 have a wonderful day misha
# 8688                               sock monkey hat ftw
# 8690                   look at the smoulder on ja phew
#
#                                   lemma stop  compound
# 4                           contact law team    0.0000
# 5                        uh mean lookin good    0.4404
# 6                                        bro    0.0000
# 8     nope eye go immediately even wrong arm   -0.4767
# 11                                    please    0.3182
# ...                                      ...       ...
# 8682                                   charm    0.4019
# 8683                    pick trash challenge    0.0772
# 8684            joke 439 wonderful day misha    0.7096
# 8688                     sock monkey hat ftw    0.4588
# 8690                   look smoulder ja phew    0.0000
#
# [2272 rows x 7 columns]

# %%
# Word cloud visualization.
from wordcloud import WordCloud
import seaborn as sns
import matplotlib.pyplot as plt

allWords = ' '.join([text for text in df_tweets['preprocessed']])
wordCloud = WordCloud(width=500, height=300, random_state=21, max_font_size=110).generate(allWords)

plt.imshow(wordCloud, interpolation="bilinear")
plt.axis('off')
plt.savefig('mishacollins_wordcloud.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
pd.to_datetime(df_tweets['timestamp_ms'], unit='ms')
# Out:
# 4      2021-11-01 03:20:34.658
# 5      2021-11-01 03:20:48.665
# 6      2021-11-01 03:23:05.666
# 8      2021-11-01 03:27:47.657
# 11     2021-11-01 03:46:13.663
#                  ...
# 8682   2022-11-21 14:03:13.660
# 8683   2022-11-21 14:19:40.661
# 8684   2022-11-21 16:05:37.658
# 8688   2022-11-22 18:02:34.664
# 8690   2022-11-22 22:01:25.658
# Name: timestamp_ms, Length: 2272, dtype: datetime64[ns]

# %%
df_timeSA = df_tweets[['timestamp_ms', 'compound']]

# %%
df_timeSA['timestamp_ms'] = pd.to_datetime(df_timeSA['timestamp_ms'], unit='ms')
# Out:
# C:\Users\Juliet\AppData\Local\Temp\ipykernel_11032\1732158251.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_timeSA['timestamp_ms'] = pd.to_datetime(df_timeSA['timestamp_ms'], unit='ms')

# %%
df_timeSA
# Out:
#                 timestamp_ms  compound
# 4    2021-11-01 03:20:34.658    0.0000
# 5    2021-11-01 03:20:48.665    0.4404
# 6    2021-11-01 03:23:05.666    0.0000
# 8    2021-11-01 03:27:47.657   -0.4767
# 11   2021-11-01 03:46:13.663    0.3182
# ...                      ...       ...
# 8682 2022-11-21 14:03:13.660    0.4019
# 8683 2022-11-21 14:19:40.661    0.0772
# 8684 2022-11-21 16:05:37.658    0.7096
# 8688 2022-11-22 18:02:34.664    0.4588
# 8690 2022-11-22 22:01:25.658    0.0000
#
# [2272 rows x 2 columns]

# %%
df_timeSA = df_timeSA.set_index('timestamp_ms').resample('D')['compound'].mean()

# %%
df_timeSA #pandas series resampled by day, taking the average sentiment of the day (mean of compound score)
# Out:
# timestamp_ms
# 2021-11-01    0.246906
# 2021-11-02    0.549575
# 2021-11-03    0.163525
# 2021-11-04    0.280778
# 2021-11-05    0.205844
#                 ...
# 2022-11-18    0.292029
# 2022-11-19    0.402933
# 2022-11-20    0.232893
# 2022-11-21    0.387475
# 2022-11-22    0.229400
# Freq: D, Name: compound, Length: 387, dtype: float64

# %%
df_timeSA.plot() #this is a plot of average sentiment by day. Very noisy. Will resample by week.
plt.xlabel('Date')
plt.ylabel('Mean sentiment')
plt.title('Average sentiment by day on tweets about "Misha Collins" from November 2021 to November 2022')
# Out:
# Text(0.5, 1.0, 'Average sentiment by day on tweets about "Misha Collins" from November 2021 to November 2022')

# %%
df_timeSA.resample('W').mean().plot()
plt.xlabel('Date')
plt.ylabel('Mean sentiment')
plt.title('Average sentiment by week on tweets about "Misha Collins" from November 2021 to November 2022')
# Out:
# Text(0.5, 1.0, 'Average sentiment by week on tweets about "Misha Collins" from November 2021 to November 2022')
